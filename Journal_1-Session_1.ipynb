# %% [markdown]
# # Coding Journal #1
# #Write a Python program to print out your full name
# #your preferred pronouns
# #sentence about your favorite movie
# #sentence about your favorite food

# %%
first_name = 'Andrew'
last_name = 'Cordova'
favorite_movie = 'Cars 1'
favorite_food = 'Chicken Nuggets'

print(f"Hello, my name is {first_name} {last_name}. My favorite movie is {favorite_movie} because I’ve loved Lightning McQueen since I was little. {favorite_food} have always been my go to because it’s one of the only foods I don't get tired of.")
# Out:
# Hello, my name is Andrew Cordova. My favorite movie is Cars 1 because I’ve loved Lightning McQueen since I was little. Chicken Nuggets have always been my go to because it’s one of the only foods I don't get tired of.
